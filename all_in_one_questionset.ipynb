# %% [markdown]
# ##### Arrays / Lists (1–10)

# %%
# Two Sum
# Given an array of integers nums and an integer target, return indices of two numbers that add up to target.
# Input: nums = [2,7,11,15], target = 9 → Output: [0,1]

def two_sum(input: list[int], target: int):
    result = {}
    for i, num in enumerate(input):
        req = target - num
        if req in result:
            return [result[req], i]
        result[num] = i


input = [2,7,11,15]
target = 9
print(two_sum(input, target))
# Out:
# [0, 1]

# %%
# Contains Duplicate
# Return True if any value appears at least twice.

def is_duplicate(l1):
    return len(l1) > len(set(l1))


l1 = [1,2,3,4,5,5]
print(is_duplicate(l1))
# Out:
# True

# %%
def binary_search(nums: list[int], target: int)-> int:
    '''
    To find the index of target integer using Binary search algorithm
    NOTE: BSA is done only in sorted list
    params:
        nums : list of integeers
        target: integer to find its index

    returns:
        result: int -> the index of the target integer 
    '''

    start = 0
    end = len(nums)-1

    while start <= end:
        mid = (start+end)//2
        if nums[mid] == target:
            return mid

        elif nums[mid] < target:
            start = mid + 1

        else:
            end = mid - 1

    return -1

# %%
nums = [1,2,23,43,234,4234]
target = 2
print(binary_search(nums, target))
# Out:
# 1

# %%
n = 124
sum = 0
while n>0:
    remainder = n % 10
    sum = sum + remainder
    n = n // 10

print(sum)

# %%
# Two Sum
# Given an array of integers nums and an integer target, return indices of two numbers that add up to target.
# Input: nums = [2,7,11,15], target = 9 → Output: [0,1]


def two_sum(arr, target):
    result = {}
    for i, num in enumerate(arr):
        required = target - num 
        if required in result:
            return [result[required], i]
        result[num] = i


input = [2,7,11,15]
target = 9
print(two_sum(input, target))
# Out:
# [0, 1]

# %%
def two_sum(arr, target):
    arr.sort()
    print('sorted array: ', arr)
    start = 0
    end = len(arr)-1

    while start<end:
        sum = arr[start] + arr[end] 
        if sum == target:
            return [start, end]
        if sum > target:
            end -= 1
        if sum < target:
            start += 1 


input = [2,7,11,15]
target = 9
print(two_sum(input, target))
# Out:
# sorted array:  [2, 7, 11, 15]
# [0, 1]

# %%
class BankAccount:
    def __init__(self):
        self.__balance = 0   # private variable

    def deposit(self, amount):
        self.__balance += amount

    def get_balance(self):
        return self.__balance

# %%
acc = BankAccount()
acc.deposit(1000)
print(acc.get_balance())
# Out:
# 1000

# %%
print(dir(acc))
# Out:
# ['_BankAccount__balance', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'deposit', 'get_balance']

# %%
acc._BankAccount__balance
# Out:
# 1000

# %%
from functools import reduce


lst = [40,20,15]
mult = reduce(lambda x,y: x*y, lst)
mult
# Out:
# 12000

# %%
odd = list(filter(lambda x: x%2 != 0, lst))
print(odd)
# Out:
# [15]
